# %%
import pandas as pd             # data package
import matplotlib.pyplot as plt # graphics 
import datetime as dt
import numpy as np
from census import Census # This is new...

import requests, io             # internet and input tools  
import zipfile as zf            # zip file tools 
import os  

#import weightedcalcs as wc
#import numpy as np

import pyarrow as pa
import pyarrow.parquet as pq
 
from bokeh.palettes import brewer, Spectral6
from bokeh.io import show, output_file, curdoc
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, Panel, Tabs, GeoJSONDataSource, LinearColorMapper
from bokeh.models import ColorBar
from bokeh.layouts import column, gridplot, row
from bokeh.transform import factor_cmap
from bokeh.models import NumeralTickFormatter, Title, Label, Paragraph, Div, CustomJSHover, BoxAnnotation

# %%
crl = ["darkblue","slategray","slategray","crimson","crimson"]

background = "#ffffff"

# %%
my_key = "&key=34e40301bda77077e24c859c6c6c0b721ad73fc7"
# This is my key. I'm nice and I have it posted. If you will be doing more with this
# please get your own key

# %%
end_use = "hs?get=CTY_NAME,CON_VAL_MO,CAL_DUT_MO,I_COMMODITY,I_COMMODITY_SDESC"

surl = "https://api.census.gov/data/timeseries/intltrade/imports/" + end_use 

surl  = surl + my_key + "&time=" + "from+2024-01" + "&COMM_LVL=HS4" 

url = surl + "&CTY_CODE=" + "1220"

# Mexico is 2010
# Canada is 1220
    
r = requests.get(url) 
    
print(r)
    
df = pd.DataFrame(r.json()[1:]) # This then converts it to a dataframe
    # Note that the first entry is the labels

df.columns = r.json()[0]

df.time = pd.to_datetime(df.time, format="%Y-%m")

df["imports"] = df["CON_VAL_MO"].astype(float)
        
df["hs2"] = df["I_COMMODITY"].astype(str)

df.drop(["CON_VAL_MO", "I_COMMODITY", "COMM_LVL"], axis = 1, inplace = True)
# Out:
# <Response [200]>

# %%
df.head()
# Out:
#   CTY_NAME CAL_DUT_MO                                  I_COMMODITY_SDESC  \
# 0   CANADA          0             HORSES, ASSES, MULES AND HINNIES, LIVE
# 1   CANADA        208                               BOVINE ANIMALS, LIVE
# 2   CANADA          0                                        SWINE, LIVE
# 3   CANADA          0                              SHEEP AND GOATS, LIVE
# 4   CANADA          0  CHICKENS, DUCKS, GEESE, TURKEYS, AND GUINEAS, ...
#
#         time CTY_CODE      imports   hs2
# 0 2024-01-01     1220    3854246.0  0101
# 1 2024-01-01     1220  104271503.0  0102
# 2 2024-01-01     1220   39974869.0  0103
# 3 2024-01-01     1220      90724.0  0104
# 4 2024-01-01     1220    3477554.0  0105

# %%
df["share"] = df.imports / df.imports.sum()

# %%
grp = df.groupby(["hs2"])

top_products = grp.agg({"imports":"sum", "I_COMMODITY_SDESC":"first", "share": "sum"})

# %%
top_products.sort_values(by = ["imports"], ascending = False)[0:20]
# Out:
#            imports                                  I_COMMODITY_SDESC  \
# hs2
# 2709  8.840692e+10   CRUDE OIL FROM PETROLEUM AND BITUMINOUS MINERALS
# 8703  2.616701e+10     MOTOR CARS & VEHICLES FOR TRANSPORTING PERSONS
# 9801  1.393975e+10   EXPTS OF REPAIRED IMPTS; IMPTS OF RETURNED EXPTS
# 2710  1.164553e+10   OIL (NOT CRUDE) FROM PETROL & BITUM MINERAL ETC.
# 8708  1.057380e+10  PARTS & ACCESS FOR MOTOR VEHICLES (HEAD 8701-8...
# 2711  7.873917e+09       PETROLEUM GASES & OTHER GASEOUS HYDROCARBONS
# 7601  7.090415e+09                                ALUMINUM, UNWROUGHT
# 8704  6.458951e+09              MOTOR VEHICLES FOR TRANSPORT OF GOODS
# 8411  5.514112e+09  TURBOJETS, TURBOPROPELLERS & OTH GAS TURBINES,...
# 8802  5.429312e+09    AIRCRAFT, POWERED; SPACECRAFT & LAUNCH VEHICLES
# 1905  4.959155e+09  BREAD, PASTRY, CAKES ETC; COMM WAFRS, EMP CAPS...
# 4407  4.841875e+09  WOOD SAWN OR CHIPPED LENGTH, SLICED ETC, OV6MM TH
# 3004  4.040642e+09  MEDICAMENTS NESOI, MIXED OR NOT, IN DOSAGE ETC FM
# 1514  3.827932e+09  RAPESEED, COLZA OR MUSTARD OIL ETC, NOT CHEM M...
# 7108  3.692871e+09   GOLD (INCL PLAT PLATED), UNWR, SEMIMFR OR POWDER
# 3901  3.160915e+09             POLYMERS OF ETHYLENE, IN PRIMARY FORMS
# 3104  2.777857e+09          MINERAL OR CHEMICAL FERTILIZERS, POTASSIC
# 2713  2.746457e+09  PETROLEUM COKE, PETROLEUM BITUMEN & OTHER RESI...
# 9403  2.696692e+09                  FURNITURE NESOI AND PARTS THEREOF
# 9999  2.536795e+09  SALVAGE;ESTIMATE OF LOW VALUED IMPORT TRANSACT...
#
#          share
# hs2
# 2709  0.234427
# 8703  0.069387
# 9801  0.036964
# 2710  0.030880
# 8708  0.028038
# 2711  0.020879
# 7601  0.018802
# 8704  0.017127
# 8411  0.014622
# 8802  0.014397
# 1905  0.013150
# 4407  0.012839
# 3004  0.010715
# 1514  0.010150
# 7108  0.009792
# 3901  0.008382
# 3104  0.007366
# 2713  0.007283
# 9403  0.007151
# 9999  0.006727

# %%
def make_source(df):
    
    df["position"] = df.reset_index().index.values
        
    df["hover_label"] = (df["imports"]/1000000000).map('{:,.1f}'.format)
    
    df["hover_label_2"] = (df["share"]*100).map('{:,.1f}'.format)
    
    source = ColumnDataSource(df)
    
    return source

# %%
def make_bar_chart(df):

    width = 600
    height = 500

    source = make_source(df)
        
    p = figure(plot_height=height, plot_width = width, title= "Top US Imports from Canada at HS4-level",
           toolbar_location = 'below',
           tools = "reset")
        
    p.vbar(x = "position", top = "imports", width = 0.6, alpha = 0.65,
       hatch_pattern = " ",hatch_alpha = 0.10, color = "color",
       source = source)

##########################################################################
    TIMETOOLTIPS = """
    <div style="background-color:#F5F5F5; opacity: 0.95; border: 0px 0px 0px 0px">
        <div style = "text-align:left;">
            <span style="font-size: 13px; font-weight: bold">@name</span>
        </div>
        <div style = "text-align:left;">
            <span style="font-size: 13px; font-weight: bold">2024 Imports: $@hover_label Billion</span>
        </div>
        <div style = "text-align:left;">
            <span style="font-size: 13px; font-weight: bold">Share of Total: @hover_label_2%</span>
        </div>
    </div>
    """

    p.add_tools(HoverTool(tooltips = TIMETOOLTIPS))
##########################################################################

    #p.ygrid.grid_line_color = None
    p.xgrid.grid_line_color = None
    
    p.title.text_font_size = '13pt'
    p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
    p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks
    p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels

    p.yaxis.formatter = NumeralTickFormatter(format="($0. a)")
    p.yaxis.minor_tick_line_color = None
    p.y_range.start = 0 
    
    p.y_range.end = 90000000000
    
    p.border_fill_color = background    
    
    p.background_fill_color = background 
    p.background_fill_alpha = 0.75    
    
    p.toolbar.autohide = True
    
    p.outline_line_color = None
    p.sizing_mode= "scale_both"
    p.max_height = height
    p.max_width = width
    p.min_height = int(0.25*height)
    p.min_width = int(0.25*width)
    return p

# %%
foo = top_products.sort_values(by = ["imports"], ascending = False)[0:20]

foo["hs-code"] = foo.index

foo["name"] = "HS4 " + foo["hs-code"] + ": " + foo["I_COMMODITY_SDESC"].str[0:30]

foo["color"] = "#ff0000"

# %%
p = make_bar_chart(foo)

# %%
show(p)

# %%
canada = make_bar_chart(foo)
    
output_file('.\\docs\\' + "us_imports_canada.html")

div0 = Div(text = """Each bar represents the total sum of U.S. imports from Canada in 2024 (through November) for an HS4 category. 
The top 20 import categories are displayed. Hover your cursor over each bar to learn more.
""", max_width=600, background = background )
div0.sizing_mode= "scale_both"
        
outfig = column(canada, div0, sizing_mode="scale_both")

show(outfig)
